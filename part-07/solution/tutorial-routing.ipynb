# %% [markdown]
# # Tutorial VII - Periodic Library Routing
#
# Applied Optimization with Julia
#
# # Introduction
#
# Welcome to “FastDelivery” - a local logistics service in Hamburg! We’re
# working with a central warehouse that operates a decentralized
# distribution network: they deliver packages directly to smaller
# distribution centers in the region, ensuring efficient last-mile
# delivery across the area.
#
# The central warehouse operates a fleet of delivery vehicles that
# transport packages between their main hub and 14 partner distribution
# centers scattered across the region. The challenge? Designing the most
# efficient routing system to keep packages flowing smoothly while keeping
# operational costs in check.
#
# In this case study, we’ll help FastDelivery optimize their delivery
# routes using the Capacitated Vehicle Routing Problem (CVRP) approach.
# We’ll consider several real-world constraints like vehicle capacity
# (measured in standard shipping containers), driving distances, and
# operational costs to find the best possible delivery strategy.
#
# # 1. Implementing the basic CVRP
#
# Implement the CVRP from the lecture without the constraints preventing
# subtours and restricting the driving time and capacities.
#
# The demand per distribution center and the coordinates of the locations
# are provided as CSV files.
#
# The number of vehicles is 6 and each vehicle can transport up to 50
# parcels to the distribution centers. Note that capacity of each vehicle
# is identical.
#
# ## Loading the data
#
# First, we load the data from the CSV files.

# %%
using DelimitedFiles
using CSV
using DataFrames
using JuMP
using HiGHS
using Plots

## Prepare the model data
file_directory = "$(@__DIR__)/../data"
demand = CSV.read("$(file_directory)/demand.csv", DataFrame)
coord = CSV.read("$(file_directory)/coord_x_y.csv", DataFrame)
# Out:
# 15×3 DataFrame
#  Row │ location  x         y
#      │ String7   Float64   Float64
# ─────┼─────────────────────────────────
#    1 │ central   155.24    151.63
#    2 │ dc_01     128.513    67.4002
#    3 │ dc_02      47.6949  194.738
#    4 │ dc_03      93.6483  181.213
#    5 │ dc_04      59.737   166.434
#    6 │ dc_05     197.681   102.756
#    7 │ dc_06     152.263   140.986
#    8 │ dc_07     183.943   182.649
#    9 │ dc_08     113.792    33.3626
#   10 │ dc_09     172.555    82.9658
#   11 │ dc_10      77.4372   27.0503
#   12 │ dc_11     132.689   152.717
#   13 │ dc_12      54.2646    0.0399352
#   14 │ dc_13      54.5474   31.4915
#   15 │ dc_14      66.5128  100.22

# %% [markdown]
# > **Tip**
# >
# > Make sure that you have downloaded the data in the `data` folder that
# > is located in the same directory as this notebook.
#
# ## Define the parameters
#
# First, define the number of vehicles and the capacity as parameters.
# Name them `vehicles` and `capacity`.

# %%
# YOUR CODE BELOW
vehicles = 6
capacity = 50
# Out:
# 50

# %%
# Test your code
@assert vehicles == 30/5 "Number of vehicles is incorrect"
@assert capacity == 100/2 "Capacity is incorrect"
println("Variables defined, great job!")
# Out:
# Variables defined, great job!

# %% [markdown]
# Now, we need to compute the distance matrix. You can do so by using the
# Euclidean distance between the coordinates of the locations. Compute the
# distance matrix for all locations and store it in a dictionary called
# `distance`. Access each location by the tuple `(i,j)` where `i` is the
# origin and `j` is the destination. **Hint: You need the distance from
# each location to all other locations!**

# %%
# YOUR CODE BELOW
distance = Dict()
for loc1 in eachrow(coord)
    for loc2 in eachrow(coord)
        println(loc1,"--/n",loc2)
        println("**")
        distance[(loc1.location,loc2.location)] = sqrt((loc1.y - loc2.y)^2 + (loc1.x - loc2.x)^2)
    end
end

# Print the first 10 entries of the distance dictionary
println("First 10 entries of the distance dictionary:")
for (k,v) in first(distance,10)
    println(k, " -> ", v)
end
# Out:
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503--/nDataFrameRow
# ...
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    1 │ central    155.24   151.63
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    2 │ dc_01     128.513  67.4002
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    3 │ dc_02     47.6949  194.738
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    4 │ dc_03     93.6483  181.213
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    5 │ dc_04      59.737  166.434
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    6 │ dc_05     197.681  102.756
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    7 │ dc_06     152.263  140.986
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    8 │ dc_07     183.943  182.649
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#    9 │ dc_08     113.792  33.3626
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   10 │ dc_09     172.555  82.9658
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   11 │ dc_10     77.4372  27.0503
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   12 │ dc_11     132.689  152.717
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼──────────────────────────────
#   13 │ dc_12     54.2646  0.0399352
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   14 │ dc_13     54.5474  31.4915
# **
# DataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22--/nDataFrameRow
#  Row │ location  x        y
#      │ String7   Float64  Float64
# ─────┼────────────────────────────
#   15 │ dc_14     66.5128   100.22
# **
# First 10 entries of the distance dictionary:
# (String7("dc_09"), String7("dc_06")) -> 61.46578650175317
# (String7("dc_02"), String7("dc_05")) -> 175.94501185623176
# (String7("dc_14"), String7("dc_04")) -> 66.55933647992104
# (String7("dc_06"), String7("dc_05")) -> 59.36648948685735
# (String7("dc_07"), String7("dc_13")) -> 198.97681774241477
# (String7("dc_08"), String7("dc_14")) -> 81.88579096984047
# (String7("dc_09"), String7("dc_10")) -> 110.33520901671315
# (String7("dc_06"), String7("dc_02")) -> 117.57434093261851
# (String7("dc_06"), String7("dc_10")) -> 136.30882974418455
# (String7("central"), String7("dc_01")) -> 88.3680381684265

# %%
# Test your code
@assert length(distance) == nrow(coord) * nrow(coord) "Distance dictionary should have n² entries where n is the number of locations"
@assert all(v >= 0 for v in values(distance)) "All distances should be non-negative"
@assert all(isapprox(distance[(i,j)], distance[(j,i)]) for i in coord.location for j in coord.location if i != j) "Distances should be symmetric"
println("Distance dictionary test passed successfully, great job!")
# Out:
# Distance dictionary test passed successfully, great job!

# %% [markdown]
# ## Define the model
#
# Next, we create the model instance. As this is a linear problem, we can
# use the `HiGHS` solver.

# %%
# Create the model instance
cvrp_model = Model(HiGHS.Optimizer)
set_attribute(cvrp_model, "presolve", "on")
set_attribute(cvrp_model, "time_limit", 60.0)
set_attribute(cvrp_model, "mip_rel_gap", 0.0)

# %% [markdown]
# ## Define the variables
#
# Now you can start by defining the model variables. The variable we need
# first is the binary decision variable `X` which indicates whether an arc
# from node `i` to node `j` exists. To work with the decision variable,
# you will need to work with a vector of locations.

# %%
# Vector of locations
println(demand.location)
# Out:
# String7["central", "dc_01", "dc_02", "dc_03", "dc_04", "dc_05", "dc_06", "dc_07", "dc_08", "dc_09", "dc_10", "dc_11", "dc_12", "dc_13", "dc_14"]

# %% [markdown]
# > **Tip**
# >
# > You could use the `demand.location` vector to define the elements of
# > the decision variable `X`.

# %%
# YOUR CODE BELOW
@variable(cvrp_model, X[demand.location,demand.location], Bin)       # 1, if arc from node to node exists
# Out:
# 2-dimensional DenseAxisArray{VariableRef,2,...} with index sets:
#     Dimension 1, String7["central", "dc_01", "dc_02", "dc_03", "dc_04", "dc_05", "dc_06", "dc_07", "dc_08", "dc_09", "dc_10", "dc_11", "dc_12", "dc_13", "dc_14"]
#     Dimension 2, String7["central", "dc_01", "dc_02", "dc_03", "dc_04", "dc_05", "dc_06", "dc_07", "dc_08", "dc_09", "dc_10", "dc_11", "dc_12", "dc_13", "dc_14"]
# And data, a 15×15 Matrix{VariableRef}:
#  X[central,central]  X[central,dc_01]  …  X[central,dc_13]  X[central,dc_14]
#  X[dc_01,central]    X[dc_01,dc_01]       X[dc_01,dc_13]    X[dc_01,dc_14]
#  X[dc_02,central]    X[dc_02,dc_01]       X[dc_02,dc_13]    X[dc_02,dc_14]
#  X[dc_03,central]    X[dc_03,dc_01]       X[dc_03,dc_13]    X[dc_03,dc_14]
#  X[dc_04,central]    X[dc_04,dc_01]       X[dc_04,dc_13]    X[dc_04,dc_14]
#  X[dc_05,central]    X[dc_05,dc_01]    …  X[dc_05,dc_13]    X[dc_05,dc_14]
#  X[dc_06,central]    X[dc_06,dc_01]       X[dc_06,dc_13]    X[dc_06,dc_14]
#  X[dc_07,central]    X[dc_07,dc_01]       X[dc_07,dc_13]    X[dc_07,dc_14]
#  X[dc_08,central]    X[dc_08,dc_01]       X[dc_08,dc_13]    X[dc_08,dc_14]
#  X[dc_09,central]    X[dc_09,dc_01]       X[dc_09,dc_13]    X[dc_09,dc_14]
#  X[dc_10,central]    X[dc_10,dc_01]    …  X[dc_10,dc_13]    X[dc_10,dc_14]
#  X[dc_11,central]    X[dc_11,dc_01]       X[dc_11,dc_13]    X[dc_11,dc_14]
#  X[dc_12,central]    X[dc_12,dc_01]       X[dc_12,dc_13]    X[dc_12,dc_14]
#  X[dc_13,central]    X[dc_13,dc_01]       X[dc_13,dc_13]    X[dc_13,dc_14]
#  X[dc_14,central]    X[dc_14,dc_01]       X[dc_14,dc_13]    X[dc_14,dc_14]

# %%
# Test your code
@assert size(X) == (15,15) "Have you defined the decision variable X?"
@assert all(is_binary(x) for x in X) "The decision variable X should be binary"
println("Decision variable X test passed successfully, great job!")
# Out:
# Decision variable X test passed successfully, great job!

# %% [markdown]
# ## Define the objective function
#
# We want to minimize the total distance of the routes based on the
# distance dictionary `distance` that you computed earlier. Create the
# objective function.

# %%
# YOUR CODE BELOW
@objective(cvrp_model, Min, 
    sum(distance[i,j] * X[i,j] for i in demand.location, j in demand.location if i != j)
    )

# %%
# Test your code
obj = objective_function(cvrp_model)
@assert typeof(obj) <: GenericAffExpr "Objective should be a linear expression"
@assert length(obj.terms) > 0 "Objective should not be empty"
println("Objective function defined successfully, great job!")
println("Note, that it is not tested whether the objective function is correct!")
# Out:
# Objective function defined successfully, great job!
# Note, that it is not tested whether the objective function is correct!

# %% [markdown]
# ## Define the constraints
#
# Create the constraints that ensure that each location is visited exactly
# once. **Note that the central location is indexed as `"central"`!** We
# don’t need to consider the central location for the constraints and we
# have to ensure during summing that we don’t include the pairs where
# `i == j`.

# %%
# YOUR CODE BELOW
@constraint(cvrp_model, inflow[j in demand.location; j != "central"], 
    sum(X[i,j] for i in demand.location if i != j) == 1
    )
@constraint(cvrp_model, outflow[i in demand.location; i != "central"], 
    sum(X[i,j] for j in demand.location if i != j) == 1
    )
# Out:
# JuMP.Containers.SparseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}, 1, Tuple{String7}} with 14 entries:
#   [dc_01]  =  outflow[dc_01] : X[dc_01,central] + X[dc_01,dc_02] + X[dc_01,dc_03] + X[dc_01,dc_04] + X[dc_01,dc_05] + X[dc_01,dc_06] + X[dc_01,dc_07] + X[dc_01,dc_08] + X[dc_01,dc_09] + X[dc_01,dc_10] + X[dc_01,dc_11] + X[dc_01,dc_12] + X[dc_01,dc_13] + X[dc_01,dc_14] = 1
#   [dc_02]  =  outflow[dc_02] : X[dc_02,central] + X[dc_02,dc_01] + X[dc_02,dc_03] + X[dc_02,dc_04] + X[dc_02,dc_05] + X[dc_02,dc_06] + X[dc_02,dc_07] + X[dc_02,dc_08] + X[dc_02,dc_09] + X[dc_02,dc_10] + X[dc_02,dc_11] + X[dc_02,dc_12] + X[dc_02,dc_13] + X[dc_02,dc_14] = 1
#   [dc_03]  =  outflow[dc_03] : X[dc_03,central] + X[dc_03,dc_01] + X[dc_03,dc_02] + X[dc_03,dc_04] + X[dc_03,dc_05] + X[dc_03,dc_06] + X[dc_03,dc_07] + X[dc_03,dc_08] + X[dc_03,dc_09] + X[dc_03,dc_10] + X[dc_03,dc_11] + X[dc_03,dc_12] + X[dc_03,dc_13] + X[dc_03,dc_14] = 1
#   [dc_04]  =  outflow[dc_04] : X[dc_04,central] + X[dc_04,dc_01] + X[dc_04,dc_02] + X[dc_04,dc_03] + X[dc_04,dc_05] + X[dc_04,dc_06] + X[dc_04,dc_07] + X[dc_04,dc_08] + X[dc_04,dc_09] + X[dc_04,dc_10] + X[dc_04,dc_11] + X[dc_04,dc_12] + X[dc_04,dc_13] + X[dc_04,dc_14] = 1
#   [dc_05]  =  outflow[dc_05] : X[dc_05,central] + X[dc_05,dc_01] + X[dc_05,dc_02] + X[dc_05,dc_03] + X[dc_05,dc_04] + X[dc_05,dc_06] + X[dc_05,dc_07] + X[dc_05,dc_08] + X[dc_05,dc_09] + X[dc_05,dc_10] + X[dc_05,dc_11] + X[dc_05,dc_12] + X[dc_05,dc_13] + X[dc_05,dc_14] = 1
#   [dc_06]  =  outflow[dc_06] : X[dc_06,central] + X[dc_06,dc_01] + X[dc_06,dc_02] + X[dc_06,dc_03] + X[dc_06,dc_04] + X[dc_06,dc_05] + X[dc_06,dc_07] + X[dc_06,dc_08] + X[dc_06,dc_09] + X[dc_06,dc_10] + X[dc_06,dc_11] + X[dc_06,dc_12] + X[dc_06,dc_13] + X[dc_06,dc_14] = 1
#   [dc_07]  =  outflow[dc_07] : X[dc_07,central] + X[dc_07,dc_01] + X[dc_07,dc_02] + X[dc_07,dc_03] + X[dc_07,dc_04] + X[dc_07,dc_05] + X[dc_07,dc_06] + X[dc_07,dc_08] + X[dc_07,dc_09] + X[dc_07,dc_10] + X[dc_07,dc_11] + X[dc_07,dc_12] + X[dc_07,dc_13] + X[dc_07,dc_14] = 1
#   [dc_08]  =  outflow[dc_08] : X[dc_08,central] + X[dc_08,dc_01] + X[dc_08,dc_02] + X[dc_08,dc_03] + X[dc_08,dc_04] + X[dc_08,dc_05] + X[dc_08,dc_06] + X[dc_08,dc_07] + X[dc_08,dc_09] + X[dc_08,dc_10] + X[dc_08,dc_11] + X[dc_08,dc_12] + X[dc_08,dc_13] + X[dc_08,dc_14] = 1
#   [dc_09]  =  outflow[dc_09] : X[dc_09,central] + X[dc_09,dc_01] + X[dc_09,dc_02] + X[dc_09,dc_03] + X[dc_09,dc_04] + X[dc_09,dc_05] + X[dc_09,dc_06] + X[dc_09,dc_07] + X[dc_09,dc_08] + X[dc_09,dc_10] + X[dc_09,dc_11] + X[dc_09,dc_12] + X[dc_09,dc_13] + X[dc_09,dc_14] = 1
#   [dc_10]  =  outflow[dc_10] : X[dc_10,central] + X[dc_10,dc_01] + X[dc_10,dc_02] + X[dc_10,dc_03] + X[dc_10,dc_04] + X[dc_10,dc_05] + X[dc_10,dc_06] + X[dc_10,dc_07] + X[dc_10,dc_08] + X[dc_10,dc_09] + X[dc_10,dc_11] + X[dc_10,dc_12] + X[dc_10,dc_13] + X[dc_10,dc_14] = 1
#   [dc_11]  =  outflow[dc_11] : X[dc_11,central] + X[dc_11,dc_01] + X[dc_11,dc_02] + X[dc_11,dc_03] + X[dc_11,dc_04] + X[dc_11,dc_05] + X[dc_11,dc_06] + X[dc_11,dc_07] + X[dc_11,dc_08] + X[dc_11,dc_09] + X[dc_11,dc_10] + X[dc_11,dc_12] + X[dc_11,dc_13] + X[dc_11,dc_14] = 1
#            ⋮
#   [dc_12]  =  outflow[dc_12] : X[dc_12,central] + X[dc_12,dc_01] + X[dc_12,dc_02] + X[dc_12,dc_03] + X[dc_12,dc_04] + X[dc_12,dc_05] + X[dc_12,dc_06] + X[dc_12,dc_07] + X[dc_12,dc_08] + X[dc_12,dc_09] + X[dc_12,dc_10] + X[dc_12,dc_11] + X[dc_12,dc_13] + X[dc_12,dc_14] = 1
#   [dc_13]  =  outflow[dc_13] : X[dc_13,central] + X[dc_13,dc_01] + X[dc_13,dc_02] + X[dc_13,dc_03] + X[dc_13,dc_04] + X[dc_13,dc_05] + X[dc_13,dc_06] + X[dc_13,dc_07] + X[dc_13,dc_08] + X[dc_13,dc_09] + X[dc_13,dc_10] + X[dc_13,dc_11] + X[dc_13,dc_12] + X[dc_13,dc_14] = 1
#   [dc_14]  =  outflow[dc_14] : X[dc_14,central] + X[dc_14,dc_01] + X[dc_14,dc_02] + X[dc_14,dc_03] + X[dc_14,dc_04] + X[dc_14,dc_05] + X[dc_14,dc_06] + X[dc_14,dc_07] + X[dc_14,dc_08] + X[dc_14,dc_09] + X[dc_14,dc_10] + X[dc_14,dc_11] + X[dc_14,dc_12] + X[dc_14,dc_13] = 1

# %%
# Test your code
const_refs = all_constraints(cvrp_model, include_variable_in_set_constraints=false)
num_constraints_in_model = length(const_refs)
expected_constraints = 2 * (nrow(demand) - 1)  # indegree + outdegree for all nodes except central
@assert num_constraints_in_model == expected_constraints "Number of constraints is incorrect as it is $(num_constraints_in_model) instead of $(expected_constraints)."
println("Constraints for the inflow and outflow defined, great job!")
# Out:
# Constraints for the inflow and outflow defined, great job!

# %% [markdown]
# Next, we need to restrict the ingoing and outgoing flows to the
# `central` location. Create the constraints that ensure that the number
# of vehicles arriving and leaving the central location is equal to the
# number of vehicles.

# %%
# YOUR CODE BELOW
@constraint(cvrp_model, vehicles_in, 
    sum(X[i,"central"] for i in demand.location if i != "central") == vehicles
    )
@constraint(cvrp_model, vehicles_out, 
    sum(X["central",j] for j in demand.location if j != "central") == vehicles
    )

# %%
# Test your code
const_refs = all_constraints(cvrp_model, include_variable_in_set_constraints=false)
num_constraints_in_model = length(const_refs)
expected_constraints = 2 * (nrow(demand) - 1) + 2  # indegree + outdegree for all nodes except central + 2 for inflow and outflow
@assert num_constraints_in_model == expected_constraints "Number of constraints is incorrect as it is $(num_constraints_in_model) instead of $(expected_constraints)."
println("Constraints for the inflow and outflow defined, great job!")
# Out:
# Constraints for the inflow and outflow defined, great job!

# %% [markdown]
# ## Solve the model
#
# Now, we can solve the model. This should work very fast, as the model is
# very simple without any subtour elimination constraints. Solve the model
# as usual.

# %%
# YOUR CODE BELOW
optimize!(cvrp_model)
# Out:
# Running HiGHS 1.8.1 (git hash: 4a7f24ac6): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [1e+00, 1e+00]
#   Cost   [1e+01, 2e+02]
#   Bound  [1e+00, 1e+00]
#   RHS    [1e+00, 6e+00]
# Presolving model
# 30 rows, 210 cols, 420 nonzeros  0s
# 30 rows, 210 cols, 420 nonzeros  0s
#
# Solving MIP model with:
#    30 rows
#    210 cols (210 binary, 0 integer, 0 implied int., 0 continuous)
#    420 nonzeros
# MIP-Timing:     0.00077 - starting analytic centre calculation
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   0               inf                  inf        0      0      0         0     0.0s
#  T       0       0         0   0.00%   0               887.1007889      100.00%        0      0      0        41     0.0s
#          1       0         1 100.00%   887.1007889     887.1007889        0.00%        0      0      0        41     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      887.100788854
#   Dual bound        887.100788854
#   Gap               0%
#   P-D integral      1.62499491125e-05
#   Solution status   feasible
#                     887.100788854 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     41 (total)
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)

# %%
# This defines a function that prints the status of the model
function print_model_status(model)
    begin
        if termination_status(model) == OPTIMAL
            println("Great, the solution is optimal.")
            println("The relative gap is $(relative_gap(model))")
            println("The solve time (in seconds) is $(solve_time(model))")
        elseif termination_status(model) == TIME_LIMIT && has_values(model)
            println("Solution is suboptimal due to a time limit, but a primal solution is available") 
        else
            error("The model was not solved correctly.") 
        end
        println("The objective value is ", objective_value(model)) 
    end
end

# Test your code
@assert termination_status(cvrp_model) == OPTIMAL "The model should be optimal. Have you have any mistakes in the model formulation?"
print_model_status(cvrp_model)
println("Model solved successfully, great job!")
# Out:
# Great, the solution is optimal.
# The relative gap is 0.0
# The solve time (in seconds) is 0.001846542116254568
# The objective value is 887.1007888539604
# Model solved successfully, great job!

# %% [markdown]
# ## Plot the results
#
# The following part extracts the results to plot the tours and requires
# no changes on your part. It defines some functions that are used to plot
# the results.

# %%
function plot_routes(X, coord)

    Routes = [value(X[i,j]) >= 0.5 ? true : false for i in coord.location, j in coord.location]

    fig = plot(
        size=(800, 600),
        background_color=:white,
        framestyle=:box,
        grid=false,
        dpi=300
    )

    connections = findall(Routes -> !iszero(Routes), Routes .>= 0.5)

    for conn in connections
        xx = [coord[conn[1],:x]; coord[conn[2],:x]]
        yy = [coord[conn[1],:y]; coord[conn[2],:y]]
        plot!(
            fig, xx, yy,
            color=:crimson,
            label="",
            linewidth=2,
            linestyle=:solid,
            alpha=0.7
        )
    end

    scatter!(
        fig, coord[1:1,:x], coord[1:1,:y],
        marker=:star5,
        color=:black,
        markersize=15,
        label="Central Library",
        markerstrokewidth=1
    )
    scatter!(
        fig, coord[2:end,:x], coord[2:end,:y],
        marker=:circle,
        color=:steelblue,
        markersize=8,
        label="Libraries",
        markerstrokewidth=1
    )

    plot!(
        fig,
        title="Delivery Routes Optimization",
        xlabel="Distance (km)",
        ylabel="Distance (km)",
        legend=:bottomright,
        legendfontsize=8,
        foreground_color_legend=nothing,
        background_color_legend=:transparent,
        margin=5Plots.mm,
        xlims=(minimum(coord.x) - 5, maximum(coord.x) + 5),
        ylims=(minimum(coord.y) - 5, maximum(coord.y) + 5)
    )

    return fig
end

# Plot the routes
display(plot_routes(X,coord))
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ## 2. Subtour elimination
#
# As you see in the plot, the solution contains subtours. Thus, we need to
# add some constraints from the Miller-Tucker-Zemlin (MTZ) formulation to
# prevent subtours. First, we need to define the variable `U` which is the
# current capacity usage at node `i`.
#
# > **Tip**
# >
# > It might be useful to convert the `demand` DataFrame into a
# > dictionary, so we can access the demand for each location directly by
# > the location name for the variable definition and the constraints.
#
# Create the variable `U` and ensure that the capacity usage at each
# location is between the demand and the capacity.

# %%
# YOUR CODE BELOW
demand_dict = Dict(demand.location .=> demand.demand)
@variable(cvrp_model, demand_dict[i] .<= U[i = demand.location] .<= capacity)
# Out:
# 1-dimensional DenseAxisArray{VariableRef,1,...} with index sets:
#     Dimension 1, String7["central", "dc_01", "dc_02", "dc_03", "dc_04", "dc_05", "dc_06", "dc_07", "dc_08", "dc_09", "dc_10", "dc_11", "dc_12", "dc_13", "dc_14"]
# And data, a 15-element Vector{VariableRef}:
#  U[central]
#  U[dc_01]
#  U[dc_02]
#  U[dc_03]
#  U[dc_04]
#  U[dc_05]
#  U[dc_06]
#  U[dc_07]
#  U[dc_08]
#  U[dc_09]
#  U[dc_10]
#  U[dc_11]
#  U[dc_12]
#  U[dc_13]
#  U[dc_14]

# %%
# Test your code
demand_dict = Dict(demand.location .=> demand.demand)
@assert all(has_lower_bound(U[i]) == true for i in demand.location) "The variable U should have a lower bound"
@assert all(has_upper_bound(U[i]) == true for i in demand.location) "The variable U should have an upper bound"
println("Variable U defined successfully, great job!")
# Out:
# Variable U defined successfully, great job!

# %% [markdown]
# Next, we need to add the constraints to prevent subtours.

# %%
# YOUR CODE BELOW
@constraint(
    cvrp_model, 
    no_subtour[
        i in demand.location, j in demand.location; 
        j != "central" && i != "central" && 
        i != j
    ], 
    U[i] - U[j] + capacity * X[i,j] <= capacity - demand_dict[j]
    )
# Out:
# JuMP.Containers.SparseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 2, Tuple{String7, String7}} with 182 entries:
#   [dc_01, dc_02]  =  no_subtour[dc_01,dc_02] : 50 X[dc_01,dc_02] + U[dc_01] - U[dc_02] ≤ 47
#   [dc_01, dc_03]  =  no_subtour[dc_01,dc_03] : 50 X[dc_01,dc_03] + U[dc_01] - U[dc_03] ≤ 47
#   [dc_01, dc_04]  =  no_subtour[dc_01,dc_04] : 50 X[dc_01,dc_04] + U[dc_01] - U[dc_04] ≤ 48
#   [dc_01, dc_05]  =  no_subtour[dc_01,dc_05] : 50 X[dc_01,dc_05] + U[dc_01] - U[dc_05] ≤ 38
#   [dc_01, dc_06]  =  no_subtour[dc_01,dc_06] : 50 X[dc_01,dc_06] + U[dc_01] - U[dc_06] ≤ 44
#   [dc_01, dc_07]  =  no_subtour[dc_01,dc_07] : 50 X[dc_01,dc_07] + U[dc_01] - U[dc_07] ≤ 48
#   [dc_01, dc_08]  =  no_subtour[dc_01,dc_08] : 50 X[dc_01,dc_08] + U[dc_01] - U[dc_08] ≤ 43
#   [dc_01, dc_09]  =  no_subtour[dc_01,dc_09] : 50 X[dc_01,dc_09] + U[dc_01] - U[dc_09] ≤ 48
#   [dc_01, dc_10]  =  no_subtour[dc_01,dc_10] : 50 X[dc_01,dc_10] + U[dc_01] - U[dc_10] ≤ 43
#   [dc_01, dc_11]  =  no_subtour[dc_01,dc_11] : 50 X[dc_01,dc_11] + U[dc_01] - U[dc_11] ≤ 38
#   [dc_14, dc_03]  =  no_subtour[dc_14,dc_03] : 50 X[dc_14,dc_03] - U[dc_03] + U[dc_14] ≤ 47
#                   ⋮
#   [dc_14, dc_04]  =  no_subtour[dc_14,dc_04] : 50 X[dc_14,dc_04] - U[dc_04] + U[dc_14] ≤ 48
#   [dc_14, dc_05]  =  no_subtour[dc_14,dc_05] : 50 X[dc_14,dc_05] - U[dc_05] + U[dc_14] ≤ 38
#   [dc_14, dc_06]  =  no_subtour[dc_14,dc_06] : 50 X[dc_14,dc_06] - U[dc_06] + U[dc_14] ≤ 44
#   [dc_14, dc_07]  =  no_subtour[dc_14,dc_07] : 50 X[dc_14,dc_07] - U[dc_07] + U[dc_14] ≤ 48
#   [dc_14, dc_08]  =  no_subtour[dc_14,dc_08] : 50 X[dc_14,dc_08] - U[dc_08] + U[dc_14] ≤ 43
#   [dc_14, dc_09]  =  no_subtour[dc_14,dc_09] : 50 X[dc_14,dc_09] - U[dc_09] + U[dc_14] ≤ 48
#   [dc_14, dc_10]  =  no_subtour[dc_14,dc_10] : 50 X[dc_14,dc_10] - U[dc_10] + U[dc_14] ≤ 43
#   [dc_14, dc_11]  =  no_subtour[dc_14,dc_11] : 50 X[dc_14,dc_11] - U[dc_11] + U[dc_14] ≤ 38
#   [dc_14, dc_12]  =  no_subtour[dc_14,dc_12] : 50 X[dc_14,dc_12] - U[dc_12] + U[dc_14] ≤ 41
#   [dc_14, dc_13]  =  no_subtour[dc_14,dc_13] : 50 X[dc_14,dc_13] - U[dc_13] + U[dc_14] ≤ 38

# %%
# Test your code
println("Constraints for the subtour elimination defined!")
println("It is not tested whether the constraints are correct, so please check the resulting routes in the visualization.")
# Out:
# Constraints for the subtour elimination defined!
# It is not tested whether the constraints are correct, so please check the resulting routes in the visualization.

# %% [markdown]
# Now, solve the model again and plot the routes.

# %%
# YOUR CODE BELOW
optimize!(cvrp_model)
print_model_status(cvrp_model)
display(plot_routes(X,coord))
# Out:
# Coefficient ranges:
#   Matrix [1e+00, 5e+01]
#   Cost   [1e+01, 2e+02]
#   Bound  [1e+00, 5e+01]
#   RHS    [1e+00, 5e+01]
# Presolving model
# 212 rows, 224 cols, 966 nonzeros  0s
# 212 rows, 224 cols, 966 nonzeros  0s
#
# Solving MIP model with:
#    212 rows
#    224 cols (210 binary, 0 integer, 0 implied int., 14 continuous)
#    966 nonzeros
# MIP-Timing:      0.0012 - starting analytic centre calculation
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   0               inf                  inf        0      0      0         0     0.0s
#          0       0         0   0.00%   890.0536182     inf                  inf        0      0      0        43     0.0s
#  R       0       0         0   0.00%   934.1145531     1133.065266       17.56%       96     13      0        65     0.0s
#  L       0       0         0   0.00%   935.573614      955.7319435        2.11%      424     34     42       108     0.1s
#
# 74.3% inactive integer columns, restarting
# Model after restart has 62 rows, 63 cols (52 bin., 0 int., 0 impl., 11 cont.), and 224 nonzeros
#
#          0       0         0   0.00%   935.573614      955.7319435        2.11%       12      0      0       464     0.1s
#          0       0         0   0.00%   935.573614      955.7319435        2.11%       12      9      7       483     0.1s
#
# 11.5% inactive integer columns, restarting
# Model after restart has 54 rows, 54 cols (44 bin., 0 int., 0 impl., 10 cont.), and 190 nonzeros
#
#          0       0         0   0.00%   935.573614      955.7319435        2.11%       12      0      0       614     0.1s
#          0       0         0   0.00%   935.573614      955.7319435        2.11%       12      9      7       646     0.1s
#          7       0         4 100.00%   955.7319435     955.7319435        0.00%      280     12    114      1554     0.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      955.73194355
#   Dual bound        955.73194355
#   Gap               0%
#   P-D integral      0.0146925179697
#   Solution status   feasible
#                     955.73194355 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            0.18 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 4
#   Nodes             7
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     1554 (total)
#                     623 (strong br.)
#                     192 (separation)
#                     499 (heuristics)
# Great, the solution is optimal.
# The relative gap is 0.0
# The solve time (in seconds) is 0.18440245813690126
# The objective value is 955.731943549865
# <img src="data:image/png;base64,..." />

# %% [markdown]
# The following code plots the capacity usage per vehicle.

# %%
# Plot the capacity usage
function plot_capacity_usage(X, U, coord)
    # Find which locations are visited by each vehicle from central
    vehicle_routes = []
    for i in coord.location
        if value(X[i, "central"]) > 0.5
            push!(vehicle_routes, (i, value(U[i])))
        end
    end

    println(vehicle_routes)
    
    # Sort by capacity usage for better visualization
    sort!(vehicle_routes, by = x -> x[2])
    
    # Create bar plot
    fig = bar(
        [u[2] for u in vehicle_routes],
        title="Capacity Usage per Vehicle",
        xlabel="Vehicle",
        ylabel="Capacity Usage (parcels)",
        label="",
        color=:steelblue,
        ylims=(0, capacity),
        size=(800, 400),
        dpi=300,
        margin=5Plots.mm,
    )
    
    # Add capacity limit line
    hline!([capacity], color=:red, linestyle=:dash, label="Capacity Limit")
    
    return fig
end

# Create and display the plot
display(plot_capacity_usage(X, U, coord))
# Out:
# Any[(String7("dc_03"), 50.0), (String7("dc_05"), 12.0), (String7("dc_06"), 6.0), (String7("dc_07"), 2.0), (String7("dc_11"), 12.0), (String7("dc_14"), 50.0)]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ## 3. Computing the costs
#
# Assume, that FastDelivery wants to know the costs of the optimal
# solution. Compute the costs of the optimal solution over the timeframe
# of four weeks with a short calculation based on the results and store
# the result in a variable called `monthly_costs`. Each driven kilometer
# is associated with costs of **0.6 EUR per kilometer** (fuel, repairs,
# and costs for the driver) and each location has to be visited daily from
# Monday to Friday. Note, that FastDelivery leases its vehicles and it has
# to pay **450 EUR every four weeks** for each vehicle in use.

# %%
# YOUR CODE BELOW
monthly_costs = objective_value(cvrp_model) * 0.6 * 4 * 5 + 450 * vehicles
println("The costs of the optimal solution over the timeframe of four weeks are $(monthly_costs) EUR.")
# Out:
# The costs of the optimal solution over the timeframe of four weeks are 14168.783322598381 EUR.

# %%
# Test your code
@assert isapprox(monthly_costs, 14168, atol=10) "The costs are not as expected. But don't worry, you can still get the bonus points!"
println("Costs calculated successfully, great job!")
# Out:
# Costs calculated successfully, great job!

# %% [markdown]
# ## 4. Optimal Solution?
#
# Although the costs can now be computed, the tour plan has not changed so
# far. FastDelivery asks you whether you have an idea of how to lower the
# costs associated with the parcel distribution. Take a look at your
# current plotted solution and try to come up with an idea. Discuss the
# potential shortcoming and assumptions of the current model in a few
# sentences. Propose at least one idea of how to lower the costs in the
# future.
#
# You can do this in a comment in the cell below.

# %%
#=
We could use a more efficient vehicle that can transport more parcels per drive. Or we could try to reduce the distance between the distribution centers in case we build new ones. Other ideas could be to reduce the number of vehicles, if we don't fully utilize them.

=#

# %% [markdown]
# ## 5. Number of Vehicles
#
# Together, you realize one potential area of improvement involves the
# number of vehicles: it might potentially not be necessary to have 6
# vehicles which deliver the parcels to the distribution centers. You are
# thus tasked to find the optimal number of vehicles and the best tour
# plan to minimize the costs **(not the distance!)**.
#
# > **Tip**
# >
# > There are multiple ways to tackle this task, but I recommend to first
# > think about how to model the fixed costs for the vehicles and how to
# > add the costs for the driving distance. If you need to adjust the
# > model, feel free to do so. The easiest way then would be the
# > definition of a new model (e.g. `cvrp_model_flex`) and then to copy
# > and adjust all relevant constraints and variables.
#
# Implement these changes in your model and compute the optimal number of
# vehicles and the best tour plan. In case the computation takes too long,
# no worries! If you define the model with a time limit of 60 seconds, it
# should not take too long.

# %%
# YOUR CODE BELOW
cvrp_model_flex = Model(HiGHS.Optimizer)
set_attribute(cvrp_model_flex, "presolve", "on")
set_attribute(cvrp_model_flex, "time_limit", 60.0)
set_attribute(cvrp_model_flex, "mip_rel_gap", 0.0)

@variable(cvrp_model_flex, X[demand.location,demand.location], Bin)
@variable(cvrp_model_flex, demand_dict[i] .<= U[i = demand.location] .<= capacity)

@objective(cvrp_model_flex, Min, 
    sum(12 * distance[i,j] * X[i,j] for i in demand.location, j in demand.location if i != j)
    + sum(450 * X["central",i] for i in demand.location if i != "central")
    )

@constraint(cvrp_model_flex, inflow[j in demand.location; j != "central"], 
    sum(X[i,j] for i in demand.location if i != j) == 1
    )
@constraint(cvrp_model_flex, outflow[i in demand.location; i != "central"], 
    sum(X[i,j] for j in demand.location if i != j) == 1
    )

@constraint(cvrp_model_flex, vehicles_in, 
    sum(X[i,"central"] for i in demand.location if i != "central") <= vehicles
    )
@constraint(cvrp_model_flex, vehicles_out, 
    sum(X["central",j] for j in demand.location if j != "central") <= vehicles
    )

@constraint(
    cvrp_model_flex, 
    no_subtour[
        i in demand.location, j in demand.location; 
        j != "central" && i != "central" && 
        i != j
    ], 
    U[i] - U[j] + capacity * X[i,j] <= capacity - demand_dict[j]
    )

optimize!(cvrp_model_flex)
# Out:
# Running HiGHS 1.8.1 (git hash: 4a7f24ac6): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [1e+00, 5e+01]
#   Cost   [1e+02, 3e+03]
#   Bound  [1e+00, 5e+01]
#   RHS    [1e+00, 5e+01]
# Presolving model
# 212 rows, 224 cols, 966 nonzeros  0s
# 212 rows, 224 cols, 966 nonzeros  0s
#
# Solving MIP model with:
#    212 rows
#    224 cols (210 binary, 0 integer, 0 implied int., 14 continuous)
#    966 nonzeros
# MIP-Timing:     0.00091 - starting analytic centre calculation
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic; L => Sub-MIP;
#      P => Empty MIP; R => Randomized rounding; S => Solve LP; T => Evaluate node; U => Unbounded;
#      z => Trivial zero; l => Trivial lower; u => Trivial upper; p => Trivial point
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   0               inf                  inf        0      0      0         0     0.0s
#          0       0         0   0.00%   7224.837666     inf                  inf        0      0      0        43     0.0s
#  R       0       0         0   0.00%   7671.163069     14018.563018      45.28%      342     27      4        94     0.0s
#  L       0       0         0   0.00%   7812.769279     10906.631231      28.37%     1580     72     20      1568     0.4s
#       3534     260      1572  39.92%   8074.951354     10906.631231      25.96%     2859     71   8716     74504     5.4s
#       8026     567      3576  47.45%   8315.112566     10906.631231      23.76%     2529     76   9974    128586    10.4s
#
# Restarting search from the root node
# Model after restart has 212 rows, 224 cols (210 bin., 0 int., 0 impl., 14 cont.), and 966 nonzeros
#
#      12453       0         0   0.00%   8474.248948     10906.631231      22.30%       59      0      0    173003    14.0s
#      12453       0         0   0.00%   8474.248948     10906.631231      22.30%       59     13      5    173026    14.0s
#      16389     228      1680  39.75%   8474.248948     10906.631231      22.30%     2083     70   9975    222245    19.0s
#      23219     664      4654  50.96%   8474.248948     10906.631231      22.30%     2331     47   9994    289001    24.0s
#      30255    1046      7727  61.80%   8571.817438     10906.631231      21.41%     2170     57   9966    356705    29.0s
#  L   34526    1290      9608  64.42%   8718.191804     10906.631231      20.07%     2319     56   9292    397918    32.5s
#      40873    1594     12379  66.03%   8795.143526     10906.631231      19.36%     2634     65   9837    460908    37.5s
#      46897    1903     15033  71.04%   8882.435158     10906.631231      18.56%     2268     53   9669    524876    42.5s
#  L   48204    1966     15621  72.05%   8885.31326      10906.631231      18.53%     2154     69   9784    537890    43.5s
#      54266    2276     18322  74.71%   8966.818174     10906.631231      17.79%     1998     57   9809    605953    49.3s
#      60956    2510     21353  77.02%   9047.072272     10906.631231      17.05%     2178     52   9708    667954    54.3s
#      66374    2758     23794  79.60%   9098.960395     10906.631231      16.57%     2083     52   9734    726784    59.3s
#      67316    2793     24220  79.74%   9106.500925     10906.631231      16.50%     2052     56   9874    736444    60.0s
#
# Solving report
#   Status            Time limit reached
#   Primal bound      10906.6312307
#   Dual bound        9106.50092513
#   Gap               16.5%
#   P-D integral      12.6772514231
#   Solution status   feasible
#                     10906.6312307 (objective)
#                     0 (bound viol.)
#                     2.10857565976e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            60.00 (total)
#                     0.00 (presolve)
#                     0.00 (solve)
#                     0.00 (postsolve)
#   Max sub-MIP depth 5
#   Nodes             67316
#   Repair LPs        0 (0 feasible; 0 iterations)
#   LP iterations     736444 (total)
#                     37282 (strong br.)
#                     52020 (separation)
#                     43747 (heuristics)

# %% [markdown]
# The code below visualizes the results. Note, that you might need to
# replace the `X` and `U` with your new models variable names, if you have
# renamed them

# %%
# Visualize the results
print_model_status(cvrp_model_flex)
display(plot_routes(X,coord))
# Out:
# Solution is suboptimal due to a time limit, but a primal solution is available
# The objective value is 10906.631230663008
# <img src="data:image/png;base64,..." />

# %%
# Test your code
display(plot_capacity_usage(X, U, coord))
# Out:
# Any[(String7("dc_03"), 47.000000000000085), (String7("dc_07"), 38.99999999999999)]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# Based on your results, what are the expected costs savings when compared
# to task b, and how many vehicles does the central library need?
#
# Please answer this question in the cell below.

# %%
#=



=#

# %% [markdown]
# –
#
# # Solutions
#
# You will likely find solutions to most exercises online. However, I
# strongly encourage you to work on these exercises independently without
# searching explicitly for the exact answers to the exercises.
# Understanding someone else’s solution is very different from developing
# your own. Use the lecture notes and try to solve the exercises on your
# own. This approach will significantly enhance your learning and
# problem-solving skills.
#
# Remember, the goal is not just to complete the exercises, but to
# understand the concepts and improve your programming abilities. If you
# encounter difficulties, review the lecture materials, experiment with
# different approaches, and don’t hesitate to ask for clarification during
# class discussions.
#
# Later, you will find the solutions to these exercises online in the
# associated GitHub repository, but we will also quickly go over them in
# next week’s tutorial. To access the solutions, click on the Github
# button on the lower right and search for the folder with today’s lecture
# and tutorial. Alternatively, you can ask ChatGPT or Claude to explain
# them to you. But please remember, the goal is not just to complete the
# exercises, but to understand the concepts and improve your programming
# abilities.
